# %%
import pandas as pd

# %%
df = pd.read_csv('Tourism.csv')

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4650      204883          1  49.0     Self Enquiry         3              9.0
# 4651      204884          1  28.0  Company Invited         1             31.0
# 4652      204885          1  52.0     Self Enquiry         3             17.0
# 4653      204886          1  19.0     Self Enquiry         3             16.0
# 4654      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4655 entries, 0 to 4654
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4655 non-null   int64
#  1   ProdTaken                 4655 non-null   int64
#  2   Age                       4559 non-null   float64
#  3   TypeofContact             4655 non-null   object
#  4   CityTier                  4655 non-null   int64
#  5   DurationOfPitch           4501 non-null   float64
#  6   Occupation                4655 non-null   object
#  7   Gender                    4655 non-null   object
#  8   NumberOfPersonVisiting    4655 non-null   int64
#  9   NumberOfFollowups         4610 non-null   float64
#  10  ProductPitched            4655 non-null   object
#  11  PreferredPropertyStar     4629 non-null   float64
#  12  MaritalStatus             4655 non-null   object
# ...

# %%
df.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4655.000000  4655.000000  4559.000000  4655.000000      4501.000000
# mean   202504.281418     0.190763    37.682606     1.659076        15.528549
# std      1410.510246     0.392945     9.332620     0.917990         8.530906
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201284.500000     0.000000    31.000000     1.000000         9.000000
# 50%    202560.000000     0.000000    36.000000     1.000000        13.000000
# 75%    203723.500000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4655.000000        4610.000000            4629.000000
# mean                 2.934694           3.732321               3.576582
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'].dropna(), bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Majority of the people travelling are between the age groups of 25 - 25. Which means they are young aspirants travelling either for business(Mostly) and a few for personal reasons or pleasure. Therefore it would be wise to come up with deals which can be accomodated for these business travellers. B2B travels are exclusive and they have easier access to airports and all their facilities are premium already, but an addition to these packages, even small gestures such as an additional snack while they travel or a cab service to their destination(if not the whole trip, maybe a discount coupon can help gain more customers for the travel agency).

# %%
prod_counts = df['ProdTaken'].value_counts()
plt.bar(prod_counts.index, prod_counts.values)
plt.xticks([0, 1], ['No', 'Yes'])
plt.xlabel('Product Taken')
plt.ylabel('Count')
plt.title('Product Taken by Customers')
plt.show()

# %% [markdown]
# A lot of people are not availing our facilities to the highest extend, that may be due to the prices or the companies we are in association with, which means, coming up with better relations and facilities provision is of utmost importance so that we can gain more customers and to retain them, we can come up with loyalty programs to get a hold on the market and capture even more market portion.

# %%
plt.scatter(df['MonthlyIncome'], df['PitchSatisfactionScore'])
plt.xlabel('Monthly Income')
plt.ylabel('Pitch Satisfaction Score')
plt.title('Monthly Income vs Pitch Satisfaction')
plt.show()

# %% [markdown]
# The satisfaction level lies on all stages and we barely see any outliers, but for the one's on a higher scale, they are not very satisfied by the services provided. Therefore, we can conclude that we are lacking behind on the services part. We must employ a customer satisfaction survey and a feedback system to gain insights as to where we are lacking and work on them immidiately. The services ranges on on 1 to 5 scale and therefore, we must work on the one's with lower ratings so that we do not lose onto those customers. A feedback system and a loyalty program with exclusive benefits can be a good way to tackle this issue.

# %%
city_tier_counts = df.groupby('CityTier').size()
plt.bar(city_tier_counts.index, city_tier_counts.values)
plt.xlabel('City Tier')
plt.ylabel('Number of Customers')
plt.title('Count of Customers by City Tier')
plt.show()

# %% [markdown]
# People are targeting lower tier cities but instead we should slowly shift our focus to mid tier cities and get people to take those packages instead of the lower tier cities. Doing so, although would increase the costs and we might lose onto the customers but, the one's who are loyal will definately upgrade and for the one's who still focus on the lower tiers, maybe coming up with better stay inn options or travel facilities can be useful. This way, we can work on retaining the lost customer share in the market. As for the upper tier cities, we must work on providing luxary facilites so that they enjoy their stays even more and come up with package criterias, such as lower tier, mid term and high tier and a 4th one, Luxary Tier packages so that people have flexibility to choose from them and they can enjoy their travels more.

# %%
plt.boxplot(df['DurationOfPitch'].dropna(), vert=False)
plt.title('Distribution of Duration of Pitch')
plt.xlabel('Duration (in minutes)')
plt.show()

# %%
occupation_count = df['Occupation'].value_counts()
plt.bar(occupation_count.index, occupation_count.values)
plt.title('Count of Customers by Occupation Type')
plt.xlabel('Occupation Type')
plt.ylabel('Count')
plt.show()

# %%
x = df['Age']
y = df['MonthlyIncome']
plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.title('Relationship between Age and Monthly Income')
plt.show()

# %%
marital_counts = df['MaritalStatus'].value_counts()
plt.bar(marital_counts.index, marital_counts.values)
plt.title('Count of Customers by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %%
passport_counts = df['Passport'].value_counts()
labels = ['Has Passport', 'No Passport']
sizes = [passport_counts[1], passport_counts[0]]
colors = ['#66b3ff','#ff9999']
explode = (0.1, 0) 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Customers with a Passport')
plt.show()

# %%
plt.scatter(df['PitchSatisfactionScore'], df['DurationOfPitch'])
plt.xlabel('Pitch Satisfaction Score')
plt.ylabel('Duration of Pitch')
plt.title('Relationship between Pitch Satisfaction Score and Duration of Pitch')
plt.show()

# %%
df['OwnCar'].value_counts().plot(kind='bar')
plt.xlabel('Owns a Car')
plt.ylabel('Count')
plt.title('Count of Customers by Car Ownership')
plt.show()

# %%
plt.boxplot(df['NumberOfFollowups'].dropna())
plt.ylabel('Number of Follow-ups')
plt.title('Distribution of Number of Follow-ups')
plt.show()

# %%
df['PreferredPropertyStar'].value_counts().plot(kind='bar')
plt.xlabel('Preferred Property Star Rating')
plt.ylabel('Count')
plt.title('Count of Customers by Preferred Property Star Rating')
plt.show()

# %% [markdown]
# People prefer lower or mid range properties which is clearly visible by the graph above, and as per the income level, this can be justified too. The number of people who opt for the loyalty program can easily be given added benefits, one of them being the property ratings. An upgrade of package to a better wstayinn can greatly increase the number of customers, because we already saw that there is a higher count of people who are not availing our services, therefore this would get us higher conversion of leads and better feedbacks and ratings on the net.

# %%
plt.scatter(df['Age'], df['PitchSatisfactionScore'])
plt.xlabel('Age')
plt.ylabel('Pitch Satisfaction Score')
plt.title('Relationship between Age and Pitch Satisfaction Score')
plt.show()

# %%
plt.hist(df['MonthlyIncome'].dropna())
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.title('Distribution of Monthly Income')
plt.show()

# %%
df['NumberOfTrips'].value_counts().plot(kind='bar')
plt.xlabel('Number of Trips Taken')
plt.ylabel('Count')
plt.title('Count of Customers by Number of Trips Taken')
plt.show()

# %% [markdown]
# The highest count of people taking repeated trips is 2, there are very few people taking more than 5 trips, that may be with the high tier classes who book the luxaries(5 star property stay ins, buying premium services for all other factors maybe). We lose on to our customers after 2 trips as the count drops significantly from 2 to 4 trips. We must come up with a system to know why is this happening by getting in touch with the customers, making them feel valued will get them to come back to our company and avail our services.

# %%
plt.scatter(df['MonthlyIncome'], df['PreferredPropertyStar'])
plt.xlabel('Monthly Income')
plt.ylabel('Preferred Property Star Rating')
plt.title('Relationship between Monthly Income and Preferred Property Star Rating')
plt.show()

# %%
df['NumberOfPersonVisiting'].value_counts().plot(kind='bar')
plt.xlabel('Number of Persons Visiting')
plt.ylabel('Count')
plt.title('Count of Customers by Number of Persons Visiting')
plt.show()

# %%
plt.boxplot([df[df['ProdTaken'] == 0]['DurationOfPitch'].dropna(), 
             df[df['ProdTaken'] == 1]['DurationOfPitch'].dropna()],
            labels=['Product Not Taken', 'Product Taken'])
plt.title('Duration of Pitch by Product Taken')
plt.xlabel('Product Taken')
plt.ylabel('Duration of Pitch')
plt.show()

# %%
df.boxplot(column='DurationOfPitch', by='Occupation')
plt.title('Duration of Pitch by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Duration of Pitch')
plt.show()

# %%
product_pitched_gender = pd.crosstab(df['ProductPitched'], df['Gender'])
product_pitched_gender.plot(kind='bar', stacked=True)
plt.title('Product Pitched by Gender')
plt.xlabel('Product Pitched')
plt.ylabel('Count')
plt.show()

# %%
marital_status_counts = df['MaritalStatus'].value_counts()
plt.pie(marital_status_counts.values, labels=marital_status_counts.index, autopct='%1.1f%%')
plt.title('Marital Status Distribution')
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
product_pitched_marital = pd.crosstab(df['ProductPitched'], df['MaritalStatus'])
product_pitched_marital.plot(kind='bar', stacked=True)
plt.title('Product Pitched by Marital Status')
plt.xlabel('Product Pitched')
plt.ylabel('Count')
plt.show()

# %%
df.groupby(['CityTier', 'Gender', 'ProdTaken']).size().unstack().plot(kind='bar', stacked=True)
plt.xlabel('City Tier and Gender')
plt.ylabel('Count')
plt.title('Product Taken by City Tier and Gender')
plt.show()

# %%
df['Designation'].value_counts().plot(kind='bar')
plt.xlabel('Designation')
plt.ylabel('Count')
plt.title('Designation Distribution')
plt.show()

# %%
df['MonthlyIncome'].plot(kind='density')
plt.xlabel('Monthly Income')
plt.title('Monthly Income Distribution')
plt.show()
